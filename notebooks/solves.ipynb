# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
cubeDf = pd.read_csv(os.path.dirname(os.getcwd()) + "\\" + "trainresults\\Cube-2,ScrambleDepth-30,Epochs-5000,lr-0.000100,residual.csv")
cubeDf.head()
# Out:
#    Epoch  Scramble Depth      Time  isSolved  Move Count  Nodes Generated  \
# 0    600               2  0.097980      True         2.0              925
# 1    600               2  0.085067      True         2.0              925
# 2    600               2  0.130374      True         2.0              925
# 3    600               2  0.084869      True         2.0              925
# 4    600               2  0.084759      True         2.0              925
#
#    Search Iterations
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4

# %%
cubeDfGroupedEpoch = cubeDf.groupby(['Scramble Depth','Epoch']).mean()
cubeDfGroupedDepth = cubeDf.groupby(['Epoch','Scramble Depth']).mean()

cubeDfGroupedEpoch
# Out:
#                            Time  isSolved  Move Count  Nodes Generated  \
# Scramble Depth Epoch
# 2              100     0.139882       1.0    1.714286       904.428571
#                200     0.076756       1.0    1.714286       794.714286
#                300     0.089427       1.0    2.000000       925.000000
#                400     0.092944       1.0    2.000000       925.000000
#                500     0.092844       1.0    2.000000       925.000000
# ...                         ...       ...         ...              ...
# 30             1000    0.720632       1.0   10.000000      7069.000000
#                2000   31.698265       1.0   10.000000    300445.000000
#                3000    0.817122       1.0   12.000000      8605.000000
#                4000    4.488026       1.0   12.000000     45469.000000
#                5000    0.794219       1.0   10.000000      8605.000000
#
#                       Search Iterations
# Scramble Depth Epoch
# ...

# %%
fig, ax = plt.subplots(figsize=(15,7))
colormap = plt.cm.gist_ncar
plt.gca().set_prop_cycle(plt.cycler('color', plt.cm.jet(np.linspace(0, 1, 14))))
cubeDfGroupedEpoch['isSolved'].unstack().plot(ax=ax)

# %%
fig, ax = plt.subplots(figsize=(15,7))
colormap = plt.cm.gist_ncar
plt.gca().set_prop_cycle(plt.cycler('color', plt.cm.jet(np.linspace(0, 1, 14))))
cubeDfGroupedDepth['isSolved'].unstack().plot(ax=ax)
